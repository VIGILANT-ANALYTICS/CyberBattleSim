# %%
# Copyright (c) Microsoft Corporation.
# Licensed under the MIT License.

"""A sample run of the CyberBattle simulation"""

from typing import cast
import gymnasium as gym
import numpy as np
import logging
import sys
import copy
from cyberbattle._env.cyberbattle_env import CyberBattleEnv
# Out:
# {}

# %%
"""Entry point if called as an executable"""

root = logging.getLogger()
root.setLevel(logging.DEBUG)

# handler = logging.StreamHandler(sys.stdout)
# handler.setLevel(logging.DEBUG)
# formatter = logging.Formatter("%(asctime)s - %(name)s - %(levelname)s - %(message)s")
# handler.setFormatter(formatter)
# root.addHandler(handler)

env = cast(CyberBattleEnv, gym.make("CyberBattleToyCtf-v0"))
# env = cast(CyberBattleEnv, gym.make("SimpleNetwork-v0"))

# %%
def greedy_search(env, depth=1):
    if depth == 0:
        return None, 0

    best_action = None
    best_reward = float("-inf")

    print(f"All valid actions in depth {depth} {env.get_all_valid_actions()}")

    for action in env.get_all_valid_actions():
        env_copy = copy.deepcopy(env)
        _, reward, done, truncated, _ = env_copy.step(action)

        if not done and not truncated:
            _, future_reward = greedy_search(env_copy, depth-1)
            reward += future_reward

        if reward > best_reward:
            best_reward = reward
            best_action = action

    return best_action, best_reward

# %%
obs, _ = env.reset()
total_reward = 0

done = False
truncated = False

while not done and not truncated:
    best_action, expected_reward = greedy_search(env, depth=1)
    print("Chosen action:", best_action, "| expected cumulative reward:", expected_reward)

    obs, reward, done, truncated, info = env.step(best_action)
    print(reward)
    total_reward += reward
    env.render()

print("Total reward collected:", total_reward)
env.close()
# Out:
# /opt/miniconda/envs/cybersim/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:127: UserWarning: WARN: The obs returned by the `reset()` method should be an int or np.int64, actual type: <class 'numpy.int32'>
#   logger.warn(f"{pre} should be an int or np.int64, actual type: {type(obs)}")
# /opt/miniconda/envs/cybersim/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.get_all_valid_actions to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_all_valid_actions` for environment variables or `env.get_wrapper_attr('get_all_valid_actions')` that will search the reminding wrappers.
#   logger.warn(
# All valid actions in depth 1 [{'local_vulnerability': array([0, 2], dtype=int32)}]
# /opt/miniconda/envs/cybersim/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:127: UserWarning: WARN: The obs returned by the `step()` method should be an int or np.int64, actual type: <class 'numpy.int32'>
#   logger.warn(f"{pre} should be an int or np.int64, actual type: {type(obs)}")
# Chosen action: {'local_vulnerability': array([0, 2], dtype=int32)} | expected cumulative reward: 11.0
# 11.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 1, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 3], dtype=int32)}, {'remote_vulnerability': array([0, 1, 4], dtype=int32)}, {'remote_vulnerability': array([0, 1, 5], dtype=int32)}, {'remote_vulnerability': array([0, 1, 6], dtype=int32)}, {'remote_vulnerability': array([0, 1, 7], dtype=int32)}]
# Chosen action: {'remote_vulnerability': array([0, 1, 5], dtype=int32)} | expected cumulative reward: 11.0
# 11.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 1, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 3], dtype=int32)}, {'remote_vulnerability': array([0, 1, 4], dtype=int32)}, {'remote_vulnerability': array([0, 1, 5], dtype=int32)}, {'remote_vulnerability': array([0, 1, 6], dtype=int32)}, {'remote_vulnerability': array([0, 1, 7], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 2], dtype=int32)}, {'remote_vulnerability': array([0, 2, 3], dtype=int32)}, {'remote_vulnerability': array([0, 2, 4], dtype=int32)}, {'remote_vulnerability': array([0, 2, 5], dtype=int32)}, {'remote_vulnerability': array([0, 2, 6], dtype=int32)}, {'remote_vulnerability': array([0, 2, 7], dtype=int32)}]
# Chosen action: {'remote_vulnerability': array([0, 2, 1], dtype=int32)} | expected cumulative reward: 14.0
# 14.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 1, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 3], dtype=int32)}, {'remote_vulnerability': array([0, 1, 4], dtype=int32)}, {'remote_vulnerability': array([0, 1, 5], dtype=int32)}, {'remote_vulnerability': array([0, 1, 6], dtype=int32)}, {'remote_vulnerability': array([0, 1, 7], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 2], dtype=int32)}, {'remote_vulnerability': array([0, 2, 3], dtype=int32)}, {'remote_vulnerability': array([0, 2, 4], dtype=int32)}, {'remote_vulnerability': array([0, 2, 5], dtype=int32)}, {'remote_vulnerability': array([0, 2, 6], dtype=int32)}, {'remote_vulnerability': array([0, 2, 7], dtype=int32)}, {'remote_vulnerability': array([0, 3, 0], dtype=int32)}, {'remote_vulnerability': array([0, 3, 1], dtype=int32)}, {'remote_vulnerability': array([0, 3, 2], dtype=int32)}, {'remote_vulnerability': array([0, 3, 3], dtype=int32)}, {'remote_vulnerability': array([0, 3, 4], dtype=int32)}, {'remote_vulnerability': array([0, 3, 5], dtype=int32)}, {'remote_vulnerability': array([0, 3, 6], dtype=int32)}, {'remote_vulnerability': array([0, 3, 7], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 0, 3, 0], dtype=int32)}, {'connect': array([0, 0, 4, 0], dtype=int32)}, {'connect': array([0, 0, 5, 0], dtype=int32)}, {'connect': array([0, 0, 6, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 1, 3, 0], dtype=int32)}, {'connect': array([0, 1, 4, 0], dtype=int32)}, {'connect': array([0, 1, 5, 0], dtype=int32)}, {'connect': array([0, 1, 6, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([0, 2, 3, 0], dtype=int32)}, {'connect': array([0, 2, 4, 0], dtype=int32)}, {'connect': array([0, 2, 5, 0], dtype=int32)}, {'connect': array([0, 2, 6, 0], dtype=int32)}, {'connect': array([0, 3, 0, 0], dtype=int32)}, {'connect': array([0, 3, 1, 0], dtype=int32)}, {'connect': array([0, 3, 2, 0], dtype=int32)}, {'connect': array([0, 3, 3, 0], dtype=int32)}, {'connect': array([0, 3, 4, 0], dtype=int32)}, {'connect': array([0, 3, 5, 0], dtype=int32)}, {'connect': array([0, 3, 6, 0], dtype=int32)}]
# Chosen action: {'connect': array([0, 3, 1, 0], dtype=int32)} | expected cumulative reward: 50.0
# 50.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 1, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 3], dtype=int32)}, {'remote_vulnerability': array([0, 1, 4], dtype=int32)}, {'remote_vulnerability': array([0, 1, 5], dtype=int32)}, {'remote_vulnerability': array([0, 1, 6], dtype=int32)}, {'remote_vulnerability': array([0, 1, 7], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 2], dtype=int32)}, {'remote_vulnerability': array([0, 2, 3], dtype=int32)}, {'remote_vulnerability': array([0, 2, 4], dtype=int32)}, {'remote_vulnerability': array([0, 2, 5], dtype=int32)}, {'remote_vulnerability': array([0, 2, 6], dtype=int32)}, {'remote_vulnerability': array([0, 2, 7], dtype=int32)}, {'remote_vulnerability': array([0, 3, 0], dtype=int32)}, {'remote_vulnerability': array([0, 3, 1], dtype=int32)}, {'remote_vulnerability': array([0, 3, 2], dtype=int32)}, {'remote_vulnerability': array([0, 3, 3], dtype=int32)}, {'remote_vulnerability': array([0, 3, 4], dtype=int32)}, {'remote_vulnerability': array([0, 3, 5], dtype=int32)}, {'remote_vulnerability': array([0, 3, 6], dtype=int32)}, {'remote_vulnerability': array([0, 3, 7], dtype=int32)}, {'remote_vulnerability': array([3, 1, 0], dtype=int32)}, {'remote_vulnerability': array([3, 1, 1], dtype=int32)}, {'remote_vulnerability': array([3, 1, 2], dtype=int32)}, {'remote_vulnerability': array([3, 1, 3], dtype=int32)}, {'remote_vulnerability': array([3, 1, 4], dtype=int32)}, {'remote_vulnerability': array([3, 1, 5], dtype=int32)}, {'remote_vulnerability': array([3, 1, 6], dtype=int32)}, {'remote_vulnerability': array([3, 1, 7], dtype=int32)}, {'remote_vulnerability': array([3, 2, 0], dtype=int32)}, {'remote_vulnerability': array([3, 2, 1], dtype=int32)}, {'remote_vulnerability': array([3, 2, 2], dtype=int32)}, {'remote_vulnerability': array([3, 2, 3], dtype=int32)}, {'remote_vulnerability': array([3, 2, 4], dtype=int32)}, {'remote_vulnerability': array([3, 2, 5], dtype=int32)}, {'remote_vulnerability': array([3, 2, 6], dtype=int32)}, {'remote_vulnerability': array([3, 2, 7], dtype=int32)}, {'remote_vulnerability': array([3, 3, 0], dtype=int32)}, {'remote_vulnerability': array([3, 3, 1], dtype=int32)}, {'remote_vulnerability': array([3, 3, 2], dtype=int32)}, {'remote_vulnerability': array([3, 3, 3], dtype=int32)}, {'remote_vulnerability': array([3, 3, 4], dtype=int32)}, {'remote_vulnerability': array([3, 3, 5], dtype=int32)}, {'remote_vulnerability': array([3, 3, 6], dtype=int32)}, {'remote_vulnerability': array([3, 3, 7], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 0, 3, 0], dtype=int32)}, {'connect': array([0, 0, 4, 0], dtype=int32)}, {'connect': array([0, 0, 5, 0], dtype=int32)}, {'connect': array([0, 0, 6, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 1, 3, 0], dtype=int32)}, {'connect': array([0, 1, 4, 0], dtype=int32)}, {'connect': array([0, 1, 5, 0], dtype=int32)}, {'connect': array([0, 1, 6, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([0, 2, 3, 0], dtype=int32)}, {'connect': array([0, 2, 4, 0], dtype=int32)}, {'connect': array([0, 2, 5, 0], dtype=int32)}, {'connect': array([0, 2, 6, 0], dtype=int32)}, {'connect': array([0, 3, 0, 0], dtype=int32)}, {'connect': array([0, 3, 1, 0], dtype=int32)}, {'connect': array([0, 3, 2, 0], dtype=int32)}, {'connect': array([0, 3, 3, 0], dtype=int32)}, {'conn ...
# Chosen action: {'remote_vulnerability': array([0, 1, 6], dtype=int32)} | expected cumulative reward: 11.0
# 11.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 1, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 3], dtype=int32)}, {'remote_vulnerability': array([0, 1, 4], dtype=int32)}, {'remote_vulnerability': array([0, 1, 5], dtype=int32)}, {'remote_vulnerability': array([0, 1, 6], dtype=int32)}, {'remote_vulnerability': array([0, 1, 7], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 2], dtype=int32)}, {'remote_vulnerability': array([0, 2, 3], dtype=int32)}, {'remote_vulnerability': array([0, 2, 4], dtype=int32)}, {'remote_vulnerability': array([0, 2, 5], dtype=int32)}, {'remote_vulnerability': array([0, 2, 6], dtype=int32)}, {'remote_vulnerability': array([0, 2, 7], dtype=int32)}, {'remote_vulnerability': array([0, 3, 0], dtype=int32)}, {'remote_vulnerability': array([0, 3, 1], dtype=int32)}, {'remote_vulnerability': array([0, 3, 2], dtype=int32)}, {'remote_vulnerability': array([0, 3, 3], dtype=int32)}, {'remote_vulnerability': array([0, 3, 4], dtype=int32)}, {'remote_vulnerability': array([0, 3, 5], dtype=int32)}, {'remote_vulnerability': array([0, 3, 6], dtype=int32)}, {'remote_vulnerability': array([0, 3, 7], dtype=int32)}, {'remote_vulnerability': array([0, 4, 0], dtype=int32)}, {'remote_vulnerability': array([0, 4, 1], dtype=int32)}, {'remote_vulnerability': array([0, 4, 2], dtype=int32)}, {'remote_vulnerability': array([0, 4, 3], dtype=int32)}, {'remote_vulnerability': array([0, 4, 4], dtype=int32)}, {'remote_vulnerability': array([0, 4, 5], dtype=int32)}, {'remote_vulnerability': array([0, 4, 6], dtype=int32)}, {'remote_vulnerability': array([0, 4, 7], dtype=int32)}, {'remote_vulnerability': array([3, 1, 0], dtype=int32)}, {'remote_vulnerability': array([3, 1, 1], dtype=int32)}, {'remote_vulnerability': array([3, 1, 2], dtype=int32)}, {'remote_vulnerability': array([3, 1, 3], dtype=int32)}, {'remote_vulnerability': array([3, 1, 4], dtype=int32)}, {'remote_vulnerability': array([3, 1, 5], dtype=int32)}, {'remote_vulnerability': array([3, 1, 6], dtype=int32)}, {'remote_vulnerability': array([3, 1, 7], dtype=int32)}, {'remote_vulnerability': array([3, 2, 0], dtype=int32)}, {'remote_vulnerability': array([3, 2, 1], dtype=int32)}, {'remote_vulnerability': array([3, 2, 2], dtype=int32)}, {'remote_vulnerability': array([3, 2, 3], dtype=int32)}, {'remote_vulnerability': array([3, 2, 4], dtype=int32)}, {'remote_vulnerability': array([3, 2, 5], dtype=int32)}, {'remote_vulnerability': array([3, 2, 6], dtype=int32)}, {'remote_vulnerability': array([3, 2, 7], dtype=int32)}, {'remote_vulnerability': array([3, 3, 0], dtype=int32)}, {'remote_vulnerability': array([3, 3, 1], dtype=int32)}, {'remote_vulnerability': array([3, 3, 2], dtype=int32)}, {'remote_vulnerability': array([3, 3, 3], dtype=int32)}, {'remote_vulnerability': array([3, 3, 4], dtype=int32)}, {'remote_vulnerability': array([3, 3, 5], dtype=int32)}, {'remote_vulnerability': array([3, 3, 6], dtype=int32)}, {'remote_vulnerability': array([3, 3, 7], dtype=int32)}, {'remote_vulnerability': array([3, 4, 0], dtype=int32)}, {'remote_vulnerability': array([3, 4, 1], dtype=int32)}, {'remote_vulnerability': array([3, 4, 2], dtype=int32)}, {'remote_vulnerability': array([3, 4, 3], dtype=int32)}, {'remote_vulnerability': array([3, 4, 4], dtype=int32)}, {'remote_vulnerability': array([3, 4, 5], dtype=int32)}, {'remote_vulnerability': array([3, 4, 6], dtype=int32)}, {'remote_vulnerability': array([3, 4, 7], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 0, 3, 0], dtype=int32)}, {'connect': array([0, 0, 4, 0], dtype=int32)}, {'connect': array([0, 0, 5, 0], dt ...
# Chosen action: {'remote_vulnerability': array([0, 4, 3], dtype=int32)} | expected cumulative reward: 11.0
# 11.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 1, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 3], dtype=int32)}, {'remote_vulnerability': array([0, 1, 4], dtype=int32)}, {'remote_vulnerability': array([0, 1, 5], dtype=int32)}, {'remote_vulnerability': array([0, 1, 6], dtype=int32)}, {'remote_vulnerability': array([0, 1, 7], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 2], dtype=int32)}, {'remote_vulnerability': array([0, 2, 3], dtype=int32)}, {'remote_vulnerability': array([0, 2, 4], dtype=int32)}, {'remote_vulnerability': array([0, 2, 5], dtype=int32)}, {'remote_vulnerability': array([0, 2, 6], dtype=int32)}, {'remote_vulnerability': array([0, 2, 7], dtype=int32)}, {'remote_vulnerability': array([0, 3, 0], dtype=int32)}, {'remote_vulnerability': array([0, 3, 1], dtype=int32)}, {'remote_vulnerability': array([0, 3, 2], dtype=int32)}, {'remote_vulnerability': array([0, 3, 3], dtype=int32)}, {'remote_vulnerability': array([0, 3, 4], dtype=int32)}, {'remote_vulnerability': array([0, 3, 5], dtype=int32)}, {'remote_vulnerability': array([0, 3, 6], dtype=int32)}, {'remote_vulnerability': array([0, 3, 7], dtype=int32)}, {'remote_vulnerability': array([0, 4, 0], dtype=int32)}, {'remote_vulnerability': array([0, 4, 1], dtype=int32)}, {'remote_vulnerability': array([0, 4, 2], dtype=int32)}, {'remote_vulnerability': array([0, 4, 3], dtype=int32)}, {'remote_vulnerability': array([0, 4, 4], dtype=int32)}, {'remote_vulnerability': array([0, 4, 5], dtype=int32)}, {'remote_vulnerability': array([0, 4, 6], dtype=int32)}, {'remote_vulnerability': array([0, 4, 7], dtype=int32)}, {'remote_vulnerability': array([0, 5, 0], dtype=int32)}, {'remote_vulnerability': array([0, 5, 1], dtype=int32)}, {'remote_vulnerability': array([0, 5, 2], dtype=int32)}, {'remote_vulnerability': array([0, 5, 3], dtype=int32)}, {'remote_vulnerability': array([0, 5, 4], dtype=int32)}, {'remote_vulnerability': array([0, 5, 5], dtype=int32)}, {'remote_vulnerability': array([0, 5, 6], dtype=int32)}, {'remote_vulnerability': array([0, 5, 7], dtype=int32)}, {'remote_vulnerability': array([3, 1, 0], dtype=int32)}, {'remote_vulnerability': array([3, 1, 1], dtype=int32)}, {'remote_vulnerability': array([3, 1, 2], dtype=int32)}, {'remote_vulnerability': array([3, 1, 3], dtype=int32)}, {'remote_vulnerability': array([3, 1, 4], dtype=int32)}, {'remote_vulnerability': array([3, 1, 5], dtype=int32)}, {'remote_vulnerability': array([3, 1, 6], dtype=int32)}, {'remote_vulnerability': array([3, 1, 7], dtype=int32)}, {'remote_vulnerability': array([3, 2, 0], dtype=int32)}, {'remote_vulnerability': array([3, 2, 1], dtype=int32)}, {'remote_vulnerability': array([3, 2, 2], dtype=int32)}, {'remote_vulnerability': array([3, 2, 3], dtype=int32)}, {'remote_vulnerability': array([3, 2, 4], dtype=int32)}, {'remote_vulnerability': array([3, 2, 5], dtype=int32)}, {'remote_vulnerability': array([3, 2, 6], dtype=int32)}, {'remote_vulnerability': array([3, 2, 7], dtype=int32)}, {'remote_vulnerability': array([3, 3, 0], dtype=int32)}, {'remote_vulnerability': array([3, 3, 1], dtype=int32)}, {'remote_vulnerability': array([3, 3, 2], dtype=int32)}, {'remote_vulnerability': array([3, 3, 3], dtype=int32)}, {'remote_vulnerability': array([3, 3, 4], dtype=int32)}, {'remote_vulnerability': array([3, 3, 5], dtype=int32)}, {'remote_vulnerability': array([3, 3, 6], dtype=int32)}, {'remote_vulnerability': array([3, 3, 7], dtype=int32)}, {'remote_vulnerability': array([3, 4, 0], dtype=int32)}, {'remote_vulnerability': array([3, 4, 1], dtype=int32)}, {'remote_vulnerability': array([3, 4, 2], dtype=int32)}, {'remote_vulnerability': array([3, 4, 3], dtype=int32)}, {'remote_vulnerability': array([3, 4, 4], ...
# Chosen action: {'remote_vulnerability': array([0, 5, 7], dtype=int32)} | expected cumulative reward: 14.0
# 14.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 1, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 3], dtype=int32)}, {'remote_vulnerability': array([0, 1, 4], dtype=int32)}, {'remote_vulnerability': array([0, 1, 5], dtype=int32)}, {'remote_vulnerability': array([0, 1, 6], dtype=int32)}, {'remote_vulnerability': array([0, 1, 7], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 2], dtype=int32)}, {'remote_vulnerability': array([0, 2, 3], dtype=int32)}, {'remote_vulnerability': array([0, 2, 4], dtype=int32)}, {'remote_vulnerability': array([0, 2, 5], dtype=int32)}, {'remote_vulnerability': array([0, 2, 6], dtype=int32)}, {'remote_vulnerability': array([0, 2, 7], dtype=int32)}, {'remote_vulnerability': array([0, 3, 0], dtype=int32)}, {'remote_vulnerability': array([0, 3, 1], dtype=int32)}, {'remote_vulnerability': array([0, 3, 2], dtype=int32)}, {'remote_vulnerability': array([0, 3, 3], dtype=int32)}, {'remote_vulnerability': array([0, 3, 4], dtype=int32)}, {'remote_vulnerability': array([0, 3, 5], dtype=int32)}, {'remote_vulnerability': array([0, 3, 6], dtype=int32)}, {'remote_vulnerability': array([0, 3, 7], dtype=int32)}, {'remote_vulnerability': array([0, 4, 0], dtype=int32)}, {'remote_vulnerability': array([0, 4, 1], dtype=int32)}, {'remote_vulnerability': array([0, 4, 2], dtype=int32)}, {'remote_vulnerability': array([0, 4, 3], dtype=int32)}, {'remote_vulnerability': array([0, 4, 4], dtype=int32)}, {'remote_vulnerability': array([0, 4, 5], dtype=int32)}, {'remote_vulnerability': array([0, 4, 6], dtype=int32)}, {'remote_vulnerability': array([0, 4, 7], dtype=int32)}, {'remote_vulnerability': array([0, 5, 0], dtype=int32)}, {'remote_vulnerability': array([0, 5, 1], dtype=int32)}, {'remote_vulnerability': array([0, 5, 2], dtype=int32)}, {'remote_vulnerability': array([0, 5, 3], dtype=int32)}, {'remote_vulnerability': array([0, 5, 4], dtype=int32)}, {'remote_vulnerability': array([0, 5, 5], dtype=int32)}, {'remote_vulnerability': array([0, 5, 6], dtype=int32)}, {'remote_vulnerability': array([0, 5, 7], dtype=int32)}, {'remote_vulnerability': array([0, 6, 0], dtype=int32)}, {'remote_vulnerability': array([0, 6, 1], dtype=int32)}, {'remote_vulnerability': array([0, 6, 2], dtype=int32)}, {'remote_vulnerability': array([0, 6, 3], dtype=int32)}, {'remote_vulnerability': array([0, 6, 4], dtype=int32)}, {'remote_vulnerability': array([0, 6, 5], dtype=int32)}, {'remote_vulnerability': array([0, 6, 6], dtype=int32)}, {'remote_vulnerability': array([0, 6, 7], dtype=int32)}, {'remote_vulnerability': array([3, 1, 0], dtype=int32)}, {'remote_vulnerability': array([3, 1, 1], dtype=int32)}, {'remote_vulnerability': array([3, 1, 2], dtype=int32)}, {'remote_vulnerability': array([3, 1, 3], dtype=int32)}, {'remote_vulnerability': array([3, 1, 4], dtype=int32)}, {'remote_vulnerability': array([3, 1, 5], dtype=int32)}, {'remote_vulnerability': array([3, 1, 6], dtype=int32)}, {'remote_vulnerability': array([3, 1, 7], dtype=int32)}, {'remote_vulnerability': array([3, 2, 0], dtype=int32)}, {'remote_vulnerability': array([3, 2, 1], dtype=int32)}, {'remote_vulnerability': array([3, 2, 2], dtype=int32)}, {'remote_vulnerability': array([3, 2, 3], dtype=int32)}, {'remote_vulnerability': array([3, 2, 4], dtype=int32)}, {'remote_vulnerability': array([3, 2, 5], dtype=int32)}, {'remote_vulnerability': array([3, 2, 6], dtype=int32)}, {'remote_vulnerability': array([3, 2, 7], dtype=int32)}, {'remote_vulnerability': array([3, 3, 0], dtype=int32)}, {'remote_vulnerability': array([3, 3, 1], dtype=int32)}, {'remote_vulnerability': array([3, 3, 2], dtype=int32)}, {'remote_vulnerability': array([3, 3, 3], dtype=int32)}, {'remote_vulnerability': array([3, 3, 4], ...
# Chosen action: {'connect': array([0, 6, 1, 1], dtype=int32)} | expected cumulative reward: 50.0
# 50.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 1, 2], dtype=int32)}, {'remote_vulnerability': array([0, 1, 3], dtype=int32)}, {'remote_vulnerability': array([0, 1, 4], dtype=int32)}, {'remote_vulnerability': array([0, 1, 5], dtype=int32)}, {'remote_vulnerability': array([0, 1, 6], dtype=int32)}, {'remote_vulnerability': array([0, 1, 7], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 2], dtype=int32)}, {'remote_vulnerability': array([0, 2, 3], dtype=int32)}, {'remote_vulnerability': array([0, 2, 4], dtype=int32)}, {'remote_vulnerability': array([0, 2, 5], dtype=int32)}, {'remote_vulnerability': array([0, 2, 6], dtype=int32)}, {'remote_vulnerability': array([0, 2, 7], dtype=int32)}, {'remote_vulnerability': array([0, 3, 0], dtype=int32)}, {'remote_vulnerability': array([0, 3, 1], dtype=int32)}, {'remote_vulnerability': array([0, 3, 2], dtype=int32)}, {'remote_vulnerability': array([0, 3, 3], dtype=int32)}, {'remote_vulnerability': array([0, 3, 4], dtype=int32)}, {'remote_vulnerability': array([0, 3, 5], dtype=int32)}, {'remote_vulnerability': array([0, 3, 6], dtype=int32)}, {'remote_vulnerability': array([0, 3, 7], dtype=int32)}, {'remote_vulnerability': array([0, 4, 0], dtype=int32)}, {'remote_vulnerability': array([0, 4, 1], dtype=int32)}, {'remote_vulnerability': array([0, 4, 2], dtype=int32)}, {'remote_vulnerability': array([0, 4, 3], dtype=int32)}, {'remote_vulnerability': array([0, 4, 4], dtype=int32)}, {'remote_vulnerability': array([0, 4, 5], dtype=int32)}, {'remote_vulnerability': array([0, 4, 6], dtype=int32)}, {'remote_vulnerability': array([0, 4, 7], dtype=int32)}, {'remote_vulnerability': array([0, 5, 0], dtype=int32)}, {'remote_vulnerability': array([0, 5, 1], dtype=int32)}, {'remote_vulnerability': array([0, 5, 2], dtype=int32)}, {'remote_vulnerability': array([0, 5, 3], dtype=int32)}, {'remote_vulnerability': array([0, 5, 4], dtype=int32)}, {'remote_vulnerability': array([0, 5, 5], dtype=int32)}, {'remote_vulnerability': array([0, 5, 6], dtype=int32)}, {'remote_vulnerability': array([0, 5, 7], dtype=int32)}, {'remote_vulnerability': array([0, 6, 0], dtype=int32)}, {'remote_vulnerability': array([0, 6, 1], dtype=int32)}, {'remote_vulnerability': array([0, 6, 2], dtype=int32)}, {'remote_vulnerability': array([0, 6, 3], dtype=int32)}, {'remote_vulnerability': array([0, 6, 4], dtype=int32)}, {'remote_vulnerability': array([0, 6, 5], dtype=int32)}, {'remote_vulnerability': array([0, 6, 6], dtype=int32)}, {'remote_vulnerability': array([0, 6, 7], dtype=int32)}, {'remote_vulnerability': array([3, 1, 0], dtype=int32)}, {'remote_vulnerability': array([3, 1, 1], dtype=int32)}, {'remote_vulnerability': array([3, 1, 2], dtype=int32)}, {'remote_vulnerability': array([3, 1, 3], dtype=int32)}, {'remote_vulnerability': array([3, 1, 4], dtype=int32)}, {'remote_vulnerability': array([3, 1, 5], dtype=int32)}, {'remote_vulnerability': array([3, 1, 6], dtype=int32)}, {'remote_vulnerability': array([3, 1, 7], dtype=int32)}, {'remote_vulnerability': array([3, 2, 0], dtype=int32)}, {'remote_vulnerability': array([3, 2, 1], dtype=int32)}, {'remote_vulnerability': array([3, 2, 2], dtype=int32)}, {'remote_vulnerability': array([3, 2, 3], dtype=int32)}, {'remote_vulnerability': array([3, 2, 4], dtype=int32)}, {'remote_vulnerability': array([3, 2, 5], dtype=int32)}, {'remote_vulnerability': array([3, 2, 6], dtype=int32)}, {'remote_vulnerability': array([3, 2, 7], dtype=int32)}, {'remote_vulnerability': array([3, 3, 0], dtype=int32)}, {'remote_vulnerability': array([3, 3, 1], dtype=int32)}, {'remote_vulnerability': array([3, 3, 2], dtype=int32)}, {'remote_vulnerability': array([3, 3, 3], dtype=int32)}, {'remote_vulnerability': array([3, 3, 4], ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       5 truncated = False
#       7 while not done and not truncated:
# ----> 8     best_action, expected_reward = greedy_search(env, depth=1)
#       9     print("Chosen action:", best_action, "| expected cumulative reward:", expected_reward)
#      11     obs, reward, done, truncated, info = env.step(best_action)
#
# Cell In[3], line 11, in greedy_search(env, depth)
#       8 print(f"All valid actions in depth {depth} {env.get_all_valid_actions()}")
#      10 for action in env.get_all_valid_actions():
# ---> 11     env_copy = copy.deepcopy(env)
#      12     _, reward, done, truncated, _ = env_copy.step(action)
#      14     if not done and not truncated:
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# KeyboardInterrupt:
