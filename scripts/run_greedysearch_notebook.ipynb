# %%
# Copyright (c) Microsoft Corporation.
# Licensed under the MIT License.

"""A sample run of the CyberBattle simulation"""

from typing import cast
import gymnasium as gym
import numpy as np
import logging
import sys
import copy
from cyberbattle._env.cyberbattle_env import CyberBattleEnv

# %%
"""Entry point if called as an executable"""

root = logging.getLogger()
root.setLevel(logging.DEBUG)

# handler = logging.StreamHandler(sys.stdout)
# handler.setLevel(logging.DEBUG)
# formatter = logging.Formatter("%(asctime)s - %(name)s - %(levelname)s - %(message)s")
# handler.setFormatter(formatter)
# root.addHandler(handler)

env = cast(CyberBattleEnv, gym.make("SimpleNetwork-v0"))

# %%
def greedy_search(env, depth=1):
    if depth == 0:
        return None, 0

    best_action = None
    best_reward = float("-inf")

    print(f"All valid actions in depth {depth} {env.get_all_valid_actions()}")

    for action in env.get_all_valid_actions():
        env_copy = copy.deepcopy(env)
        _, reward, done, truncated, _ = env_copy.step(action)

        if not done and not truncated:
            _, future_reward = greedy_search(env_copy, depth-1)
            reward += future_reward

        if reward > best_reward:
            best_reward = reward
            best_action = action

    return best_action, best_reward

# %%
obs, _ = env.reset()
total_reward = 0

done = False
truncated = False

while not done and not truncated:
    best_action, expected_reward = greedy_search(env, depth=1)
    print("Chosen action:", best_action, "| expected cumulative reward:", expected_reward)

    obs, reward, done, truncated, info = env.step(best_action)
    print(reward)
    total_reward += reward

print("Total reward collected:", total_reward)
env.close()
# Out:
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 11.0
# 11.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}]
# Chosen action: {'remote_vulnerability': array([0, 1, 1], dtype=int32)} | expected cumulative reward: 11.0
# 11.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}]
# Chosen action: {'remote_vulnerability': array([0, 2, 0], dtype=int32)} | expected cumulative reward: 9.0
# 9.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}]
# Chosen action: {'connect': array([0, 1, 2, 0], dtype=int32)} | expected cumulative reward: 1000.0
# 1000.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# ...
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# Chosen action: {'local_vulnerability': array([0, 0], dtype=int32)} | expected cumulative reward: 0.0
# 0.0
# All valid actions in depth 1 [{'local_vulnerability': array([0, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 0], dtype=int32)}, {'remote_vulnerability': array([0, 1, 1], dtype=int32)}, {'remote_vulnerability': array([0, 2, 0], dtype=int32)}, {'remote_vulnerability': array([0, 2, 1], dtype=int32)}, {'remote_vulnerability': array([1, 1, 0], dtype=int32)}, {'remote_vulnerability': array([1, 1, 1], dtype=int32)}, {'remote_vulnerability': array([1, 2, 0], dtype=int32)}, {'remote_vulnerability': array([1, 2, 1], dtype=int32)}, {'connect': array([0, 0, 0, 0], dtype=int32)}, {'connect': array([0, 0, 1, 0], dtype=int32)}, {'connect': array([0, 0, 2, 0], dtype=int32)}, {'connect': array([0, 1, 0, 0], dtype=int32)}, {'connect': array([0, 1, 1, 0], dtype=int32)}, {'connect': array([0, 1, 2, 0], dtype=int32)}, {'connect': array([0, 2, 0, 0], dtype=int32)}, {'connect': array([0, 2, 1, 0], dtype=int32)}, {'connect': array([0, 2, 2, 0], dtype=int32)}, {'connect': array([1, 0, 0, 0], dtype=int32)}, {'connect': array([1, 0, 1, 0], dtype=int32)}, {'connect': array([1, 0, 2, 0], dtype=int32)}, {'connect': array([1, 1, 0, 0], dtype=int32)}, {'connect': array([1, 1, 1, 0], dtype=int32)}, {'connect': array([1, 1, 2, 0], dtype=int32)}, {'connect': array([1, 2, 0, 0], dtype=int32)}, {'connect': array([1, 2, 1, 0], dtype=int32)}, {'connect': array([1, 2, 2, 0], dtype=int32)}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 8
#       5 truncated = False
#       7 while not done and not truncated:
# ----> 8     best_action, expected_reward = greedy_search(env, depth=1)
#       9     print("Chosen action:", best_action, "| expected cumulative reward:", expected_reward)
#      11     obs, reward, done, truncated, info = env.step(best_action)
#
# Cell In[41], line 11, in greedy_search(env, depth)
#       8 print(f"All valid actions in depth {depth} {env.get_all_valid_actions()}")
#      10 for action in env.get_all_valid_actions():
# ---> 11     env_copy = copy.deepcopy(env)
#      12     _, reward, done, truncated, _ = env_copy.step(action)
#      14     if not done and not truncated:
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
#     [... skipping similar frames: _deepcopy_dict at line 231 (5 times), deepcopy at line 146 (5 times), deepcopy at line 172 (4 times), _reconstruct at line 271 (3 times)]
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
#     [... skipping similar frames: _deepcopy_dict at line 231 (1 times), deepcopy at line 146 (1 times)]
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:265, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     263 if deep and args:
#     264     args = (deepcopy(arg, memo) for arg in args)
# --> 265 y = func(*args)
#     266 if deep:
#     267     memo[id(x)] = y
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:264, in <genexpr>(.0)
#     262 deep = memo is not None
#     263 if deep and args:
# --> 264     args = (deepcopy(arg, memo) for arg in args)
#     265 y = func(*args)
#     266 if deep:
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File /opt/miniconda/envs/cybersim/lib/python3.10/copy.py:138, in deepcopy(x, memo, _nil)
#     135     memo = {}
#     137 d = id(x)
# --> 138 y = memo.get(d, _nil)
#     139 if y is not _nil:
#     140     return y
#
# KeyboardInterrupt:
